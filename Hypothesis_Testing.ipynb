# %% [markdown]
# **Hypothesis Testing**

# %% [markdown]
# 1   .  What is a null hypothesis (H₀) and why is it important in hypothesis
#        testing?
#
# Ans  - A null hypothesis (H₀) is a default statement that there is on
#        effect , on difference ,or no relationship between variable .
#
# 2   .  What does the significance level (α) represent in hypothesis testing?
#
# Ans  - in hypothsis testing , the significance level (α) represents the
#       probability of rejecting the null hypothsis when its actually true
#       this is also knows as the type I error probability . typically ,α is set to 0.05, meaining theres a 5% chance of rejecting the null hypothsis if its true
#
# 3   .  Differentiate between Type I and Type II errors.
#
# Ans   - type I error - this hsppen when you reject a true null hypothsis .
#         its like falsely accusing someone whos innocent . the probability
#         of making a type i error is denoted (alpha)
#         type of II error - this occurs when you fail to reject a false null
#         hypothsis .its like letting a guilty person go free probability  of making a type ii error denoted (beta).
#
# 4    .  Explain the difference between a one-tailed and two-tailed
#          test. Give an example of each.
#
# Ans  - one tailed - tests if a parameter is grater then or less then a
#        creatin value
#        two tailed - tests if a parameter is different from a creatin value
#
# 5    .  A company claims that the average time to resolve a customer
#         complaint is 10 minutes.
#        A random sample of 9 complaints gives an average time of 12 minutes and a standard deviation of 3 minutes.At α = 0.05, test the claim.
#
# Ans   - the calculated t=2 is less than the critical t=2.306 , we fail to
#         reject the null hypothsis at α=0.05 there insufficient evidence to
#         reject the company claim that the average time customer complaint is 10 minites .
#
# 6    .  When should you use a Z-test instead of a t-test?
#
# Ans   - the sample size is large n>30
#         the population standed division is know
#         in contrast t-tests are used when sample size is small n<=30.
#
# 7    .   The productivity of 6 employees was measured before  and
#          after a training program.
#          At α = 0.05, test if the training improved productivity.
#
#
# Ans   - mean difference =(5+5+1+3+1+3)/6 =18/6=3
#         determine critical t value for α =0.05,df=n-1=5
#          α=0.05,df=5 for one trailed critical t=2.015
#          the training improved productivity at α=0.05
#
# 8     .   A company wants to test if product preference is independent of
#           gender.
#           At α = 0.05, test independence
#
# Ans   - chi squar =5+3.33+5+3.33=16.66
#         degerees of freedom =(row-1)
#         2-1 =1
#         for α =0.05 and df =1 the critical chi square value is
#         approximately 3.841.
